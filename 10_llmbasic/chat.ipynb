# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得 / 1Password管理下にある.envの読み込み
def load_env():
    path = os.path.expanduser("~/.env")

    with open(path, "r", encoding="utf-8") as f:
        env_text = f.read()

    env = {}
    for line in env_text.splitlines():
        line = line.strip()
        if not line or line.startswith("#"):
            continue
        if "=" not in line:
            continue
        key, value = line.split("=", 1)
        env[key.strip()] = value.strip()
    return env

# 環境変数の取得
env = load_env()

# OpenAI APIクライアントを生成
client = OpenAI(api_key=env["llm_dev_key"])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージの設定
message = "言語モデルを使う上でのポイントは"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ]
)

# レスポンスの表示
pprint(vars(response))

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())

# 役割や前提の設定
role = "あなたはマーケティング分野に精通したビジネスコンサルタントです。企業の成長をサポートするために、効果的なマーケティング戦略を提供します。"

# メッセージの設定
message = "新製品の発売に向けた効果的なマーケティング戦略を教えてください。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": message},
    ],
)

# 言語モデルからの回答を表示
print(response.choices[0].message.content.strip())

# 出力の多様性
message = "日本の魅力を紹介して！"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "user", "content": message},
    ],
    temperature=1.4,
    n = 3, # 3回答を得る
    max_completion_tokens = 100 # 出力トークン長を制限
)

# 結果を表示（複数回答を比較）
for choice in response.choices:
    print("-" * 20)
    print(choice.message.content.strip())
# Out:
# {'_request_id': 'req_6d3b468979c6498bb75248665ce13400',
#  'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='言語モデルを使う上でのポイントはいくつかあります。以下に主要なものを挙げます：\n\n1. **目的の明確化**:\n   - 何のために言語モデルを使いたいのか、用途を明確にすることが重要です。例えば、テキスト生成、質問応答、要約など、目的に応じて使い方が異なります。\n\n2. **入力の工夫**:\n   - モデルに与える入力の質が結果に大きく影響します。クリアで具体的なプロンプトを作成することで、より良い出力が得られます。\n\n3. **コンテキストの提供**:\n   - モデルがより正確な回答を提供するために、必要な背景情報やコンテキストを適切に与えることが重要です。\n\n4. **出力の確認**:\n   - モデルが生成したテキストは必ず確認し、正確性や適切さを評価する必要があります。特に重要な情報の場合、モデルの出力を鵜呑みにしないことが大切です。\n\n5. **フィードバックループの構築**:\n   - モデルの出力を改善するために、実際の使用に基づいてフィードバックを収集し、プロンプトを調整したり、データセットを見直したりすることが有益です。\n\n6. **倫理的配慮**:\n   - 言語モデルはバイアスを含む場合があり、生成するコンテンツに注意が必要です。倫理的な観点からも、出力が適切であるかをチェックすることが重要です。\n\n7. **制限の理解**:\n   - 言語モデルには限界があります。特に知識のカットオフや、リアルタイムの情報を持たないため、最新の情報を必要とする場合には注意が必要です。\n\n8. **用途に応じた選択**:\n   - モデルのバージョンや種類（GPT系や他のモデル）を選ぶ際、用途に応じた性能や特性を考慮することが重要です。\n\nこれらのポイントを考慮することで、言語モデルをより効果的に活用することができるでしょう。', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))],
#  'created': 1776149162,
#  'id': 'chatcmpl-DURp41SU3DOPkVNn2ZIbqxNWToVrQ',
#  'model': 'gpt-4o-mini-2024-07-18',
#  'object': 'chat.completion',
#  'service_tier': 'default',
#  'system_fingerprint': 'fp_f61dbb362a',
#  'usage': CompletionUsage(completion_tokens=528, prompt_tokens=18, total_tokens=546, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))}
# 言語モデルを使う上でのポイントはいくつかあります。以下に主要なものを挙げます：
#
# 1. **目的の明確化**:
#    - 何のために言語モデルを使いたいのか、用途を明確にすることが重要です。例えば、テキスト生成、質問応答、要約など、目的に応じて使い方が異なります。
#
# 2. **入力の工夫**:
#    - モデルに与える入力の質が結果に大きく影響します。クリアで具体的なプロンプトを作成することで、より良い出力が得られます。
#
# 3. **コンテキストの提供**:
#    - モデルがより正確な回答を提供するために、必要な背景情報やコンテキストを適切に与えることが重要です。
#
# 4. **出力の確認**:
#    - モデルが生成したテキストは必ず確認し、正確性や適切さを評価する必要があります。特に重要な情報の場合、モデルの出力を鵜呑みにしないことが大切です。
#
# 5. **フィードバックループの構築**:
#    - モデルの出力を改善するために、実際の使用に基づいてフィードバックを収集し、プロンプトを調整したり、データセットを見直したりすることが有益です。
#
# 6. **倫理的配慮**:
#    - 言語モデルはバイアスを含む場合があり、生成するコンテンツに注意が必要です。倫理的な観点からも、出力が適切であるかをチェックすることが重要です。
#
# 7. **制限の理解**:
#    - 言語モデルには限界があります。特に知識のカットオフや、リアルタイムの情報を持たないため、最新の情報を必要とする場合には注意が必要です。
#
# 8. **用途に応じた選択**:
#    - モデルのバージョンや種類（GPT系や他のモデル）を選ぶ際、用途に応じた性能や特性を考慮することが重要です。
#
# これらのポイントを考慮することで、言語モデルをより効果的に活用することができるでしょう。
# 新製品の発売に向けた効果的なマーケティング戦略は、ターゲット市場、競合環境、製品の特性によって異なりますが、以下のステップを参考にすることで成功の可能性を高めることができます。
#
# ### 1. 市場調査とターゲット設定
# - **市場調査**: 消費者のニーズ、競合の動向、トレンドを分析し、どのようなニーズに応える製品なのかを明確化します。
# - **ターゲットペルソナ**: 最も影響を受けると思われる顧客像（年齢、性別、趣味、ライフスタイルなど）を定義します。
#
# ### 2. 明確なメッセージとブランドポジショニング
# - **製品の独自性**: 競合製品との差別化ポイントを明確にし、消費者に訴えるメッセージを開発します。
# - **キャッチコピー**: 短く覚えやすいキャッチコピーを考案し、ブランドイメージを強化します。
#
# ### 3. マルチチャネルマーケティング
# - **オンライン**: ソーシャルメディア（Instagram, Twitter, Facebookなど）、公式ウェブサイト、ブログなどを活用して情報を発信します。特に、動画コンテンツやインフルエンサーとのコラボレーションが効果を発揮します。
# - **オフライン**: イベント、ポップアップストア、体験イベント、店舗でのプロモーションなど、直接顧客と接点を持つ機会を増やします。
#
# ### 4. プロモーション戦略
# - **ティーザーキャンペーン**: 発売前に少しずつ情報を出して興味を引く施策を行います。
# - **期間限定オファー**: 発売初期に特別価格やセット販売、購入特典などを提供することで購入を促進します。
#
# ### 5. 顧客の声を活用
# - **フィードバックの収集**: 発売後には、顧客からのフィードバックを収集し、製品の改善や次回のマーケティング戦略に活かします。リビューやテストモニターを通じて、消費者のリアルな声を集めます。
#
# ### 6. 継続的なエンゲージメント
# - **サポートとアフターサービス**: 顧客が製品を使った後のフォローアップを行い、満足度を高め、リピート購入を促します。
# - **コミュニティの構築**: ソーシャルメディアなどを通じてブランドに関連したコミュニティを作り、的確な情報提供や顧客同士の交流を支援します。
#
# ### 7. 成果の測定と改善
# - **KPIの設定**: 売上、ウェブサイトのトラフィック、ソーシャルメディアのエンゲージメントなど、成功を測定するための指標を設定します。
# - **PDCAサイクル**: 定期的にマーケティング戦略の成果を分析し、必要に応じて戦略を修正します。
#
# これらのステップを順を追って実行することで、新製品の市場導入が成功しやすくなります。
