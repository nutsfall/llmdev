# %% [markdown]
# ## 仕様
# 入力された元金と金利をもとに、10年後の金額を複利で予測するプログラムを作成しましょう。次の条件に従って計算を行ってください。
#
# - ユーザーが元金（初期投資額）を入力します。入力には `input()` 関数を使用してください。
# - ユーザーが年利（パーセンテージ）を入力します。入力には `input()` 関数を使用してください。
# - 繰り返し構文を使用して、10年間の金額を計算します。
#
# ### 複利とは
# **複利**とは、利子を次期の元金に組み入れる方式です。
# 元金だけでなく利子にも次期の利子が付く方式で、預金や投資などに広く採用されています。
#
# 例えば、元金が1000円、年利が5%の場合の金額は以下のように計算されます。
# 課題では、この計算を繰り返し構文を使用して行います。
#
# - 1年後：`1000 * (1 + (5 / 100)) = 1050.0`
# - 2年後：`1050.0 * (1 + (5 / 100)) = 1102.5`
# - 3年後：`1102.5 * (1 + (5 / 100)) = 1157.625 ...`
#
# ## 実行結果の例
# 元金が1000円、年利が5%の場合は、以下のような出力となります。
#
# ```text
# 元金を入力してください: 1000
# 年利を入力してください: 5
# 10年後の金額: 1628.89
# ```

# %%
initial_investment = int(input("元金を入力してください: "))
annual_interest_rate_percent = int(input("年利を入力してください: "))

balance = initial_investment

for i in range(10):
    balance = balance * ( 1 + (annual_interest_rate_percent / 100) )

print(f"元金を入力してください: {initial_investment}")
print(f"年利を入力してください: {annual_interest_rate_percent}")
print(f"10年後の金額: {balance:.2f}")
# Out:
# 元金を入力してください: 1000
# 年利を入力してください: 5
# 10年後の金額: 1628.89
