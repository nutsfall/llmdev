# %% [markdown]
# # 仕様
# 自己紹介プログラムを作成してください。
#
# 名前と年齢を格納する変数を用意して、値の代入を行ってください。
# 上記の変数を使用して、自己紹介の内容を出力してください。

# %%
# 変数
name = "栗秋宏徳"
age = 45

# 結果を表示
print(f"はじめまして、 {name} と申します。")
print(f"年齢は {age:02d} 歳です。来年は {age+1:02d} 歳になります。")
print("よろしくお願いします。")
# Out:
# はじめまして、 栗秋宏徳 と申します。
# 年齢は 45 歳です。来年は 46 歳になります。
# よろしくお願いします。
